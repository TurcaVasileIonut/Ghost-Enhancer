# %%
from Train.HighToLow import HighToLow

h2l = HighToLow()
h2l.run()
# Out:
# Epoch:  0
#  1390(0) G_h2l: 0.058, D_h2l: 0.590Average G_h2l: 0.045, D_h2l: 0.741
# Epoch:  1
#  1390(1) G_h2l: 0.159, D_h2l: 0.103Average G_h2l: 0.047, D_h2l: 0.716
# Epoch:  2
#  6(2) G_h2l: 0.050, D_h2l: 0.673
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from Train.HighToLow import HighToLow
#       3 h2l = HighToLow()
# ----> 4 h2l.run()
#
# File ~\Desktop\facultate\Licenta\image-enhancer\Train\HighToLow.py:133, in HighToLow.run(self)
#     131 loss_g_h2l.backward()
#     132 optim_g_h2l.step()
# --> 133 print("\r {}({}) G_h2l: {:.3f}, D_h2l: {:.3f}".format(i + 1, epoch, loss_g_h2l.item(), loss_d_h2l.item()), end='', flush=True)
#     134 sum_loss_d += loss_d_h2l.item()
#     135 sum_loss_g += loss_g_h2l.item()
#
# KeyboardInterrupt:
